# %%
  # import hierarchical clustering libraries
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

# %%
Univ = pd.read_excel("./Universities.xlsx")

# %%
Univ.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(Univ.iloc[:,1:])

# %%
df_norm.head()
# Out:
#         SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0  0.743902  0.847222  0.105263  0.368421  0.255144  0.900000
# 1  1.000000  1.000000  0.144737  0.000000  1.000000  0.466667
# 2  0.621951  0.472222  0.592105  0.157895  0.297461  0.166667
# 3  0.743902  0.666667  0.131579  0.315789  0.415629  0.700000
# 4  0.670732  0.763889  0.250000  0.368421  0.239835  0.766667

# %%
# create dendrogram
dendrogram = sch.dendrogram(sch.linkage(df_norm, method='average'))

# %%
# create clusters
hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'average')

# %%
# save clusters for chart

y_hc = hc.fit_predict(df_norm)
# Out:
# C:\Users\Divya\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
y_hc
# Out:
# array([3, 2, 0, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 1, 3, 1, 3, 1, 0, 3, 0, 3,
#        3, 1, 3], dtype=int64)

# %%
d1 = pd.DataFrame(y_hc)
d1
# Out:
#     0
# 0   3
# 1   2
# 2   0
# 3   3
# 4   3
# 5   3
# 6   3
# 7   3
# 8   3
# 9   2
# 10  3
# 11  3
# 12  3
# 13  1
# 14  3
# 15  1
# 16  3
# 17  1
# 18  0
# 19  3
# 20  0
# 21  3
# 22  3
# 23  1
# 24  3

# %%
d1.columns = ['Cluster_id']
d1
# Out:
#     Cluster_id
# 0            3
# 1            2
# 2            0
# 3            3
# 4            3
# 5            3
# 6            3
# 7            3
# 8            3
# 9            2
# 10           3
# 11           3
# 12           3
# 13           1
# 14           3
# 15           1
# 16           3
# 17           1
# 18           0
# 19           3
# 20           0
# 21           3
# 22           3
# 23           1
# 24           3

# %%
Clusters = pd.DataFrame(y_hc , columns=['Clusters'])

# %%
Clusters
# Out:
#     Clusters
# 0          0
# 1          0
# 2          2
# 3          0
# 4          0
# 5          0
# 6          0
# 7          0
# 8          0
# 9          0
# 10         0
# 11         0
# 12         0
# 13         1
# 14         0
# 15         1
# 16         0
# 17         1
# 18         2
# 19         0
# 20         2
# 21         0
# 22         0
# 23         1
# 24         0

# %%
#inverse_transform()  ---- to get back original data from standardized data set

# %%
df_norm['h_clusterid'] = Clusters

# %%
df_norm
# Out:
#          SAT     Top10    Accept   SFRatio  Expenses  GradRate  h_clusterid
# 0   0.743902  0.847222  0.105263  0.368421  0.255144  0.900000            0
# 1   1.000000  1.000000  0.144737  0.000000  1.000000  0.466667            0
# 2   0.621951  0.472222  0.592105  0.157895  0.297461  0.166667            2
# 3   0.743902  0.666667  0.131579  0.315789  0.415629  0.700000            0
# 4   0.670732  0.763889  0.250000  0.368421  0.239835  0.766667            0
# 5   0.817073  0.847222  0.118421  0.210526  0.427512  0.933333            0
# 6   0.756098  0.861111  0.210526  0.315789  0.416996  0.933333            0
# 7   0.609756  0.638889  0.131579  0.315789  0.208161  0.833333            0
# 8   0.963415  0.875000  0.000000  0.263158  0.561699  1.000000            0
# 9   0.731707  0.652778  0.394737  0.052632  0.910991  0.666667            0
# 10  0.914634  0.916667  0.210526  0.210526  0.476864  0.800000            0
# ...

# %%
df_norm[df_norm['h_clusterid']==2]
# Out:
#          SAT     Top10    Accept   SFRatio  Expenses  GradRate  h_clusterid
# 2   0.621951  0.472222  0.592105  0.157895  0.297461  0.166667            2
# 18  0.573171  0.930556  0.342105  0.578947  0.117293  0.366667            2
# 20  0.426829  0.513889  0.710526  0.526316  0.123307  0.600000            2

# %%
#df_norm.sort_values("h_clusterid")
