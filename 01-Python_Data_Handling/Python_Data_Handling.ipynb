# %%
import pandas as pd
import numpy as np

# %%
# !python --version
# Out:
# Python 3.9.7

# %%
# dir(pd)

# %%
#stores1 = pd.read_excel(r"C:\Users\ddp17\OneDrive\Desktop\New folder\Retail_data.xlsx" , sheet_name = 'storesdata')

# %%
# df1 = pd.read_excel("D:/01_EXCELR/02_Deep Learning & AI/Day1/Part 2/Retail_data.csv")

# %%
stores = pd.read_excel("./Retail_data.xlsx", sheet_name = 'storesdata')

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
type(stores)
# Out:
# pandas.core.frame.DataFrame

# %%
# DataFrame is a datastructure to store the data in 2D format i.e. rows and columns
# Each row called as record
# Each columns called as features/variables

# %%
# Variables in Python
# 1. Qualitative\Categorical
#     1.1 Nominal, Can not be sorted (Red, Green, Yellow)
#     1.2 Ordinal, Can be sorted (Low, Medium, High)
# 2. Continuous\Numeric [-infinity < n < +infinity]
#     2.1 Discrete - Finite posibility (No of child in a family)
#     2.2 Continuous - Infinite posibility (Age of a person)

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Code                                    29 non-null     float64
#  1   StoreType                               34 non-null     object
#  2   OperatingCost                           34 non-null     float64
#  3   Total_Sales                             34 non-null     int64
#  4   Total_Customers                         34 non-null     int64
#  5   Segment                                 34 non-null     int64
#  6   Total number of estb                    34 non-null     int64
#  7   Product line sales as % of total sales  34 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.3+ KB

# %%
stores.columns
# Out:
# Index(['Code', 'StoreType', 'OperatingCost', 'Total_Sales', 'Total_Customers',
#        'Segment', 'Total number of estb',
#        'Product line sales as % of total sales'],
#       dtype='object')

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
stores[['StoreType', 'Total_Sales', 'Segment']]
# Out:
#        StoreType  Total_Sales  Segment
# 0   Electronincs   2179474632        4
# 1        Apparel      5037027        4
# 2   Super Market   1437362017        1
# 3   Super Market   1495953548        1
# 4   Super Market   1883321582        2
# 5        Apparel   1420570094        1
# 6        Apparel   1374569510        4
# 7   Electronincs   1094166173        2
# 8   Electronincs   1182772215        2
# 9        Apparel    891982615        4
# 10  Super Market    427475654        4
# 11  Super Market   1101543654        3
# 12  Super Market    397305098        3
# 13       Apparel    960625804        3
# 14       Apparel    665220823        4
# 15  Electronincs   1070859930        4
# 16  Electronincs    755438818        4
# 17       Apparel    953515932        1
# 18  Super Market    962715247        2
# 19  Super Market    660175220        1
# 20  Super Market    672255327        1
# 21       Apparel   1333254147        2
# 22       Apparel    877566947        2
# ...

# %%
### method 1
## use dot operator

stores.StoreType
# Out:
# 0     Electronincs
# 1          Apparel
# 2     Super Market
# 3     Super Market
# 4     Super Market
# 5          Apparel
# 6          Apparel
# 7     Electronincs
# 8     Electronincs
# 9          Apparel
# 10    Super Market
# 11    Super Market
# 12    Super Market
# 13         Apparel
# 14         Apparel
# 15    Electronincs
# 16    Electronincs
# 17         Apparel
# 18    Super Market
# 19    Super Market
# 20    Super Market
# 21         Apparel
# 22         Apparel
# 23    Electronincs
# 24    Electronincs
# 25         Apparel
# 26    Super Market
# 27    Super Market
# 28    Super Market
# 29         Apparel
# 30         Apparel
# 31    Electronincs
# 32         Apparel
# 33    Electronincs
# Name: StoreType, dtype: object

# %%
### method 2
## use []

stores['Segment']
# Out:
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4
# 10    4
# 11    3
# 12    3
# 13    3
# 14    4
# 15    4
# 16    4
# 17    1
# 18    2
# 19    1
# 20    1
# 21    2
# 22    2
# 23    4
# 24    2
# 25    1
# 26    2
# 27    2
# 28    4
# 29    4
# 30    4
# 31    2
# 32    4
# 33    2
# Name: Segment, dtype: int64

# %%
stores[['Segment','Total_Sales']]
# Out:
#     Segment  Total_Sales
# 0         4   2179474632
# 1         4      5037027
# 2         1   1437362017
# 3         1   1495953548
# 4         2   1883321582
# 5         1   1420570094
# 6         4   1374569510
# 7         2   1094166173
# 8         2   1182772215
# 9         4    891982615
# 10        4    427475654
# 11        3   1101543654
# 12        3    397305098
# 13        3    960625804
# 14        4    665220823
# 15        4   1070859930
# 16        4    755438818
# 17        1    953515932
# 18        2    962715247
# 19        1    660175220
# 20        1    672255327
# 21        2   1333254147
# 22        2    877566947
# 23        4    812748470
# 24        2    766522079
# 25        1   1099171980
# 26        2    711375353
# 27        2    886631610
# 28        4     22212234
# 29        4    393363810
# 30        4   1115016252
# 31        2   1237304404
# 32        4   1115016252
# 33        2   1237304404

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
stores['Rank'] = stores['OperatingCost'].rank()
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   1.0  Electronincs           21.0   2179474632              110        4
# 1   2.0       Apparel           21.0      5037027              110        4
# 2   3.0  Super Market           22.8   1437362017               93        1
# 3   4.0  Super Market           21.4   1495953548              110        1
# 4   NaN  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  Rank
# 0                361300                                    29.6  20.5
# 1                  2515                                     5.7  20.5
# 2                200112                                     5.9  26.5
# 3                229623                                     4.6  23.0
# 4                270472                                    24.7  16.0

# %%
stores.tail()
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 29  30.0       Apparel           19.7    393363810              175        4
# 30  31.0       Apparel           15.0   1115016252              335        4
# 31  32.0  Electronincs           21.4   1237304404              109        2
# 32  31.0       Apparel           15.0   1115016252              335        4
# 33  32.0  Electronincs           21.4   1237304404              109        2
#
#     Total number of estb  Product line sales as % of total sales  Rank
# 29                 17840                                     4.2  19.0
# 30                125658                                     7.5   6.5
# 31                123206                                     6.4  23.0
# 32                125658                                     7.5   6.5
# 33                123206                                     6.4  23.0

# %%
stores.columns
# Out:
# Index(['Code', 'StoreType', 'OperatingCost', 'Total_Sales', 'Total_Customers',
#        'Segment', 'Total number of estb',
#        'Product line sales as % of total sales', 'Rank'],
#       dtype='object')

# %%
stores.columns.to_list()
# Out:
# ['Code',
#  'StoreType',
#  'OperatingCost',
#  'Total_Sales',
#  'Total_Customers',
#  'Segment',
#  'Total number of estb',
#  'Product line sales as % of total sales',
#  'Rank']

# %%
# Shape of DF [Rows, colm]
stores.shape
# Out:
# (34, 9)

# %%
stores.shape[0] # Rows
# Out:
# 34

# %%
stores.shape[1] # Columns
# Out:
# 9

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Code                                    29 non-null     float64
#  1   StoreType                               34 non-null     object
#  2   OperatingCost                           34 non-null     float64
#  3   Total_Sales                             34 non-null     int64
#  4   Total_Customers                         34 non-null     int64
#  5   Segment                                 34 non-null     int64
#  6   Total number of estb                    34 non-null     int64
#  7   Product line sales as % of total sales  34 non-null     float64
#  8   Rank                                    34 non-null     float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 2.5+ KB

# %%
stores.Segment
# Out:
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4
# 10    4
# 11    3
# 12    3
# 13    3
# 14    4
# 15    4
# 16    4
# 17    1
# 18    2
# 19    1
# 20    1
# 21    2
# 22    2
# 23    4
# 24    2
# 25    1
# 26    2
# 27    2
# 28    4
# 29    4
# 30    4
# 31    2
# 32    4
# 33    2
# Name: Segment, dtype: int64

# %%
stores['Segment']
# Out:
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4
# 10    4
# 11    3
# 12    3
# 13    3
# 14    4
# 15    4
# 16    4
# 17    1
# 18    2
# 19    1
# 20    1
# 21    2
# 22    2
# 23    4
# 24    2
# 25    1
# 26    2
# 27    2
# 28    4
# 29    4
# 30    4
# 31    2
# 32    4
# 33    2
# Name: Segment, dtype: int64

# %%
stores[['Code', 'StoreType' , 'Segment']]
# Out:
#     Code     StoreType  Segment
# 0    1.0  Electronincs        4
# 1    2.0       Apparel        4
# 2    3.0  Super Market        1
# 3    4.0  Super Market        1
# 4    NaN  Super Market        2
# 5    6.0       Apparel        1
# 6    7.0       Apparel        4
# 7    8.0  Electronincs        2
# 8    9.0  Electronincs        2
# 9   10.0       Apparel        4
# 10  11.0  Super Market        4
# 11  12.0  Super Market        3
# 12  13.0  Super Market        3
# 13  14.0       Apparel        3
# 14  15.0       Apparel        4
# 15   NaN  Electronincs        4
# 16  17.0  Electronincs        4
# 17  18.0       Apparel        1
# 18  19.0  Super Market        2
# 19  20.0  Super Market        1
# 20  21.0  Super Market        1
# 21   NaN       Apparel        2
# 22  23.0       Apparel        2
# 23  24.0  Electronincs        4
# 24  25.0  Electronincs        2
# 25  26.0       Apparel        1
# 26   NaN  Super Market        2
# 27   NaN  Super Market        2
# ...

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   1.0  Electronincs           21.0   2179474632              110        4
# 1   2.0       Apparel           21.0      5037027              110        4
# 2   3.0  Super Market           22.8   1437362017               93        1
# 3   4.0  Super Market           21.4   1495953548              110        1
# 4   NaN  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  Rank
# 0                361300                                    29.6  20.5
# 1                  2515                                     5.7  20.5
# 2                200112                                     5.9  26.5
# 3                229623                                     4.6  23.0
# 4                270472                                    24.7  16.0

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
stores['StoreType'].value_counts()
# Out:
# Apparel         13
# Super Market    12
# Electronincs     9
# Name: StoreType, dtype: int64

# %%
stores.Segment.value_counts()
# Out:
# 4    13
# 2    11
# 1     7
# 3     3
# Name: Segment, dtype: int64

# %%
stores['Segment'].unique()
# Out:
# array([4, 1, 2, 3], dtype=int64)

# %%
stores['StoreType'].unique()
# Out:
# array(['Electronincs', 'Apparel', 'Super Market'], dtype=object)

# %% [markdown]
# ### Data Structures
# * 1. List --- []
# * 2. Tuple --- ()
# * 3. Set--- {}
# * 4. Dictionary --- {'key1': '', 'value': ''}
# * 5. DataFrame ---

# %%
stores['StoreType'].dtypes
# Out:
# dtype('O')

# %%
stores['Segment'].dtypes
# Out:
# dtype('int64')

# %%
stores.dtypes.value_counts()
# Out:
# float64    4
# int64      4
# object     1
# dtype: int64

# %%
stores.columns
# Out:
# Index(['Code', 'StoreType', 'OperatingCost', 'Total_Sales', 'Total_Customers',
#        'Segment', 'Total number of estb',
#        'Product line sales as % of total sales', 'Rank'],
#       dtype='object')

# %%
stores.head(2)
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   1.0  Electronincs           21.0   2179474632              110        4
# 1   2.0       Apparel           21.0      5037027              110        4
#
#    Total number of estb  Product line sales as % of total sales  Rank
# 0                361300                                    29.6  20.5
# 1                  2515                                     5.7  20.5

# %%
stores.describe()
# Out:
#           Code  OperatingCost   Total_Sales  Total_Customers    Segment  \
# count  29.0000      34.000000  3.400000e+01        34.000000  34.000000
# mean   17.0000      19.979412  9.764656e+08       151.117647   2.647059
# std     9.9391       5.911611  4.553365e+08        74.252136   1.203086
# min     1.0000      10.400000  5.037027e+06        52.000000   1.000000
# 25%     9.0000      15.275000  7.223912e+08        99.000000   2.000000
# 50%    17.0000      19.200000  9.616705e+08       123.000000   2.000000
# 75%    25.0000      22.475000  1.223671e+09       180.000000   4.000000
# max    32.0000      33.900000  2.179475e+09       335.000000   4.000000
#
#        Total number of estb  Product line sales as % of total sales       Rank
# count             34.000000                               34.000000  34.000000
# mean          113049.647059                                7.785294  17.500000
# std            78910.801558                               10.897042   9.949874
# ...

# %%
#stores.Segment

#stores['Segment']

# %%
stores.mean()
# Out:
# C:\Users\Divya\AppData\Local\Temp\ipykernel_11812\4125046902.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   stores.mean()
# Code                                      1.700000e+01
# OperatingCost                             1.997941e+01
# Total_Sales                               9.764656e+08
# Total_Customers                           1.511176e+02
# Segment                                   2.647059e+00
# Total number of estb                      1.130496e+05
# Product line sales as % of total sales    7.785294e+00
# Rank                                      1.750000e+01
# dtype: float64

# %%
stores.Total_Sales.mean()
# Out:
# 976465554.7647059

# %%
stores.Total_Sales.median()
# Out:
# 961670525.5

# %%
stores.Total_Sales.mean() , stores.Total_Sales.median() , stores.Total_Sales.min(),  stores.Total_Sales.max()
# Out:
# (976465554.7647059, 961670525.5, 5037027, 2179474632)

# %%
stores.Total_Customers.dtypes
# Out:
# dtype('int64')

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   1.0  Electronincs           21.0   2179474632              110        4
# 1   2.0       Apparel           21.0      5037027              110        4
# 2   3.0  Super Market           22.8   1437362017               93        1
# 3   4.0  Super Market           21.4   1495953548              110        1
# 4   NaN  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  Rank
# 0                361300                                    29.6  20.5
# 1                  2515                                     5.7  20.5
# 2                200112                                     5.9  26.5
# 3                229623                                     4.6  23.0
# 4                270472                                    24.7  16.0

# %%
# loc gets rows (and/or columns) with particular labels.
     ## loc returns records from [start to end] index

# iloc gets rows (and/or columns) at integer locations
    ## iloc returns records from [start to end - 1] index

## loc[ rows, columns]
## loc[logic, 1:5]


stores.loc[ : ,"StoreType"]
# Out:
# 0     Electronincs
# 1          Apparel
# 2     Super Market
# 3     Super Market
# 4     Super Market
# 5          Apparel
# 6          Apparel
# 7     Electronincs
# 8     Electronincs
# 9          Apparel
# 10    Super Market
# 11    Super Market
# 12    Super Market
# 13         Apparel
# 14         Apparel
# 15    Electronincs
# 16    Electronincs
# 17         Apparel
# 18    Super Market
# 19    Super Market
# 20    Super Market
# 21         Apparel
# 22         Apparel
# 23    Electronincs
# 24    Electronincs
# 25         Apparel
# 26    Super Market
# 27    Super Market
# 28    Super Market
# 29         Apparel
# 30         Apparel
# 31    Electronincs
# 32         Apparel
# 33    Electronincs
# Name: StoreType, dtype: object

# %%
stores.loc[ 0:5  ,  ['StoreType', 'OperatingCost']]
# Out:
#       StoreType  OperatingCost
# 0  Electronincs           21.0
# 1       Apparel           21.0
# 2  Super Market           22.8
# 3  Super Market           21.4
# 4  Super Market           18.7
# 5       Apparel           18.1

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
stores.iloc[0:5,0:7]
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   1.0  Electronincs           21.0   2179474632              110        4
# 1   2.0       Apparel           21.0      5037027              110        4
# 2   3.0  Super Market           22.8   1437362017               93        1
# 3   4.0  Super Market           21.4   1495953548              110        1
# 4   NaN  Super Market           18.7   1883321582              175        2
#
#    Total number of estb
# 0                361300
# 1                  2515
# 2                200112
# 3                229623
# 4                270472

# %%
stores.iloc[1:3,1:4]
# Out:
#       StoreType  OperatingCost  Total_Sales
# 1       Apparel           21.0      5037027
# 2  Super Market           22.8   1437362017

# %%
stores.iloc[[1,2,10,11] , [0,1,5]]
# Out:
#     Code     StoreType  Segment
# 1    2.0       Apparel        4
# 2    3.0  Super Market        1
# 10  11.0  Super Market        4
# 11  12.0  Super Market        3

# %% [markdown]
# ### sample example of loc & iloc

# %%
s1 = pd.Series([2434,56778,1234,"A","C"], index=[49, 48, 47, 0, 1])
s1
# Out:
# 49     2434
# 48    56778
# 47     1234
# 0         A
# 1         C
# dtype: object

# %%
s1.loc[0]
# Out:
# 'A'

# %%
s1.iloc[0]
# Out:
# 2434

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   1.0  Electronincs           21.0   2179474632              110        4
# 1   2.0       Apparel           21.0      5037027              110        4
# 2   3.0  Super Market           22.8   1437362017               93        1
# 3   4.0  Super Market           21.4   1495953548              110        1
# 4   NaN  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7

# %%
### Renaming of columns

# df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})

stores1 = stores.rename(columns={"Code":"Store_Code" , "OperatingCost":"Op_Cost"})
stores1.head()
# Out:
#    Store_Code     StoreType  Op_Cost  Total_Sales  Total_Customers  Segment  \
# 0         1.0  Electronincs     21.0   2179474632              110        4
# 1         2.0       Apparel     21.0      5037027              110        4
# 2         3.0  Super Market     22.8   1437362017               93        1
# 3         4.0  Super Market     21.4   1495953548              110        1
# 4         NaN  Super Market     18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  Rank
# 0                361300                                    29.6  20.5
# 1                  2515                                     5.7  20.5
# 2                200112                                     5.9  26.5
# 3                229623                                     4.6  23.0
# 4                270472                                    24.7  16.0

# %%
#stores1.to_excel('rename_output.xlsx')

# %%
#stores1.to_csv('rename_output1.csv')

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
### adding new col.
### method 1
stores['sales_per_cust_11'] = stores.Total_Sales / stores.Total_Customers

#df['new_col'] = df.col1 + df.col2

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   1.0  Electronincs           21.0   2179474632              110        4
# 1   2.0       Apparel           21.0      5037027              110        4
# 2   3.0  Super Market           22.8   1437362017               93        1
# 3   4.0  Super Market           21.4   1495953548              110        1
# 4   NaN  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  \
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7
#
#    sales_per_cust_11  sales_per_cust1  sales_per_cust_22
# 0       1.981341e+07     1.981341e+07         2179474742
# ...

# %%
### method 2

stores = stores.assign(sales_per_cust1 = stores.Total_Sales / stores.Total_Customers , sales_per_cust_22 = stores.Total_Sales + stores.Total_Customers)

# %%
stores.head()
# Out:
#    Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0   1.0  Electronincs           21.0   2179474632              110        4
# 1   2.0       Apparel           21.0      5037027              110        4
# 2   3.0  Super Market           22.8   1437362017               93        1
# 3   4.0  Super Market           21.4   1495953548              110        1
# 4   NaN  Super Market           18.7   1883321582              175        2
#
#    Total number of estb  Product line sales as % of total sales  \
# 0                361300                                    29.6
# 1                  2515                                     5.7
# 2                200112                                     5.9
# 3                229623                                     4.6
# 4                270472                                    24.7
#
#    sales_per_cust_11  sales_per_cust1  sales_per_cust_22
# 0       1.981341e+07     1.981341e+07         2179474742
# ...

# %%
## where condition

## where(logic,T,F)

x = -10
print(np.where(x > 0, "positive","neg"))
# Out:
# neg

# %%
stores.head()
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 15   NaN  Electronincs           10.4   1070859930              215        4
# 14  15.0       Apparel           10.4    665220823              205        4
# 23  24.0  Electronincs           13.3    812748470              245        4
# 6    7.0       Apparel           14.3   1374569510              245        4
# 16  17.0  Electronincs           14.7    755438818              230        4
#
#     Total number of estb  Product line sales as % of total sales  Rank  \
# 15                 86686                                     1.3   1.5
# 14                 44954                                     5.6   1.5
# 23                 81065                                     2.1   3.0
# 6                 176243                                     2.4   4.0
# 16                 66825                                     5.2   5.0
#
#     sales_per_cust_11  sales_per_cust1  sales_per_cust_22
# ...

# %%
### binning - converting a continuous variable into categorical var.

stores['stores_level'] = np.where(stores['Total number of estb']<10000, 'Low',
                                  
                                  np.where((stores['Total number of estb']>=10000)  & (stores['Total number of estb']<30000),
                                           
                                           'Medium', 'High'))

# %%
stores.head(20)
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 15   NaN  Electronincs           10.4   1070859930              215        4
# 14  15.0       Apparel           10.4    665220823              205        4
# 23  24.0  Electronincs           13.3    812748470              245        4
# 6    7.0       Apparel           14.3   1374569510              245        4
# 16  17.0  Electronincs           14.7    755438818              230        4
# 30  31.0       Apparel           15.0   1115016252              335        4
# 32  31.0       Apparel           15.0   1115016252              335        4
# 13  14.0       Apparel           15.2    960625804              180        3
# 22  23.0       Apparel           15.2    877566947              150        2
# 21   NaN       Apparel           15.5   1333254147              150        2
# 28  29.0  Super Market           15.8     22212234              264        4
# ...

# %%
### filter records based on given conditions..

# %%
# Applying conditions on a dataframe using loc[,]

stores.loc[stores.StoreType == "Super Market" , ["StoreType","OperatingCost"]]
# Out:
#        StoreType  OperatingCost
# 28  Super Market           15.8
# 11  Super Market           16.4
# 12  Super Market           17.3
# 10  Super Market           17.8
# 4   Super Market           18.7
# 3   Super Market           21.4
# 20  Super Market           21.5
# 2   Super Market           22.8
# 26  Super Market           26.0
# 18  Super Market           30.4
# 27  Super Market           30.4
# 19  Super Market           33.9

# %%
stores.loc[(stores.OperatingCost > 20) , ["StoreType","OperatingCost"]]
# Out:
#        StoreType  OperatingCost
# 0   Electronincs           21.0
# 1        Apparel           21.0
# 3   Super Market           21.4
# 31  Electronincs           21.4
# 33  Electronincs           21.4
# 20  Super Market           21.5
# 8   Electronincs           22.8
# 2   Super Market           22.8
# 7   Electronincs           24.4
# 26  Super Market           26.0
# 25       Apparel           27.3
# 18  Super Market           30.4
# 27  Super Market           30.4
# 17       Apparel           32.4
# 19  Super Market           33.9

# %%
stores.loc[((stores.OperatingCost > 20) & (stores.OperatingCost < 30)) , ["StoreType","OperatingCost"]]
# Out:
#        StoreType  OperatingCost
# 0   Electronincs           21.0
# 1        Apparel           21.0
# 3   Super Market           21.4
# 31  Electronincs           21.4
# 33  Electronincs           21.4
# 20  Super Market           21.5
# 8   Electronincs           22.8
# 2   Super Market           22.8
# 7   Electronincs           24.4
# 26  Super Market           26.0
# 25       Apparel           27.3

# %%
stores.loc[(stores.StoreType == "Super Market")|(stores.StoreType == "Electronincs") , ["StoreType","OperatingCost"]]
# Out:
#        StoreType  OperatingCost
# 15  Electronincs           10.4
# 23  Electronincs           13.3
# 16  Electronincs           14.7
# 28  Super Market           15.8
# 11  Super Market           16.4
# 12  Super Market           17.3
# 10  Super Market           17.8
# 4   Super Market           18.7
# 24  Electronincs           19.2
# 0   Electronincs           21.0
# 3   Super Market           21.4
# 31  Electronincs           21.4
# 33  Electronincs           21.4
# 20  Super Market           21.5
# 8   Electronincs           22.8
# 2   Super Market           22.8
# 7   Electronincs           24.4
# 26  Super Market           26.0
# 18  Super Market           30.4
# 27  Super Market           30.4
# 19  Super Market           33.9

# %%
stores.loc[(stores.OperatingCost < 30) & (stores.StoreType == "Super Market") , ["StoreType","OperatingCost"]]
# Out:
#        StoreType  OperatingCost
# 28  Super Market           15.8
# 11  Super Market           16.4
# 12  Super Market           17.3
# 10  Super Market           17.8
# 4   Super Market           18.7
# 3   Super Market           21.4
# 20  Super Market           21.5
# 2   Super Market           22.8
# 26  Super Market           26.0

# %% [markdown]
# ### understand below code and output

# %%
stores.loc[((stores.OperatingCost > 20) & (stores.OperatingCost < 30)) & ((stores.StoreType == "Super Market")|(stores.StoreType == "Electronincs") | (stores.StoreType == "Apparel")) , ["StoreType","OperatingCost"]]
# Out:
#        StoreType  OperatingCost
# 0   Electronincs           21.0
# 1        Apparel           21.0
# 3   Super Market           21.4
# 31  Electronincs           21.4
# 33  Electronincs           21.4
# 20  Super Market           21.5
# 8   Electronincs           22.8
# 2   Super Market           22.8
# 7   Electronincs           24.4
# 26  Super Market           26.0
# 25       Apparel           27.3

# %%
### sort the df

Sort2 = stores.sort_values(by = "OperatingCost")
Sort2
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 15   NaN  Electronincs           10.4   1070859930              215        4
# 14  15.0       Apparel           10.4    665220823              205        4
# 23  24.0  Electronincs           13.3    812748470              245        4
# 6    7.0       Apparel           14.3   1374569510              245        4
# 16  17.0  Electronincs           14.7    755438818              230        4
# 30  31.0       Apparel           15.0   1115016252              335        4
# 32  31.0       Apparel           15.0   1115016252              335        4
# 13  14.0       Apparel           15.2    960625804              180        3
# 22  23.0       Apparel           15.2    877566947              150        2
# 21   NaN       Apparel           15.5   1333254147              150        2
# 28  29.0  Super Market           15.8     22212234              264        4
# ...

# %%
Sort2.iloc[ 0:3 , 2:5 ]
# Out:
#     OperatingCost  Total_Sales  Total_Customers
# 15           10.4   1070859930              215
# 14           10.4    665220823              205
# 23           13.3    812748470              245

# %%
Sort2 = stores.sort_values(by = "OperatingCost", ascending=False)
Sort2
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 19  20.0  Super Market           33.9    660175220               65        1
# 17  18.0       Apparel           32.4    953515932               66        1
# 27   NaN  Super Market           30.4    886631610              113        2
# 18  19.0  Super Market           30.4    962715247               52        2
# 25  26.0       Apparel           27.3   1099171980               66        1
# 26   NaN  Super Market           26.0    711375353               91        2
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 2    3.0  Super Market           22.8   1437362017               93        1
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 20  21.0  Super Market           21.5    672255327               97        1
# 33  32.0  Electronincs           21.4   1237304404              109        2
# ...

# %%
Sort4 = stores.sort_values(by = ["OperatingCost","Total number of estb"],ascending=[True,False])
Sort4
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 15   NaN  Electronincs           10.4   1070859930              215        4
# 14  15.0       Apparel           10.4    665220823              205        4
# 23  24.0  Electronincs           13.3    812748470              245        4
# 6    7.0       Apparel           14.3   1374569510              245        4
# 16  17.0  Electronincs           14.7    755438818              230        4
# 30  31.0       Apparel           15.0   1115016252              335        4
# 32  31.0       Apparel           15.0   1115016252              335        4
# 22  23.0       Apparel           15.2    877566947              150        2
# 13  14.0       Apparel           15.2    960625804              180        3
# 21   NaN       Apparel           15.5   1333254147              150        2
# 28  29.0  Super Market           15.8     22212234              264        4
# ...

# %%
#Sort4.reset_index()

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 15 to 19
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Code                                    29 non-null     float64
#  1   StoreType                               34 non-null     object
#  2   OperatingCost                           34 non-null     float64
#  3   Total_Sales                             34 non-null     int64
#  4   Total_Customers                         34 non-null     int64
#  5   Segment                                 34 non-null     int64
#  6   Total number of estb                    34 non-null     int64
#  7   Product line sales as % of total sales  34 non-null     float64
#  8   Rank                                    34 non-null     float64
#  9   sales_per_cust_11                       34 non-null     float64
# ...

# %%
## Drop column/feature

# df.drop(['feature1, feature2'], axis = 1) axis = 0/1
    # 0 - Row
    # 1 - Column

# Sort4.drop(['index'], axis=1)

# %%
### number of missing values

stores.isna().sum()
# Out:
# Code                                      5
# StoreType                                 0
# OperatingCost                             0
# Total_Sales                               0
# Total_Customers                           0
# Segment                                   0
# Total number of estb                      0
# Product line sales as % of total sales    0
# Rank                                      0
# sales_per_cust_11                         0
# sales_per_cust1                           0
# sales_per_cust_22                         0
# stores_level                              0
# dtype: int64

# %%
stores.isnull().sum()
# Out:
# Code                                      5
# StoreType                                 0
# OperatingCost                             0
# Total_Sales                               0
# Total_Customers                           0
# Segment                                   0
# Total number of estb                      0
# Product line sales as % of total sales    0
# Rank                                      0
# sales_per_cust_11                         0
# sales_per_cust1                           0
# sales_per_cust_22                         0
# stores_level                              0
# dtype: int64

# %%
#df = stores[ stores['Code'].notnull() ]

# %%
# s2 = stores[stores.Code.isnull()]
# s2

# %%
df1 = stores[ stores['Code'].notnull()    ]
df1
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 14  15.0       Apparel           10.4    665220823              205        4
# 23  24.0  Electronincs           13.3    812748470              245        4
# 6    7.0       Apparel           14.3   1374569510              245        4
# 16  17.0  Electronincs           14.7    755438818              230        4
# 30  31.0       Apparel           15.0   1115016252              335        4
# 32  31.0       Apparel           15.0   1115016252              335        4
# 13  14.0       Apparel           15.2    960625804              180        3
# 22  23.0       Apparel           15.2    877566947              150        2
# 28  29.0  Super Market           15.8     22212234              264        4
# 11  12.0  Super Market           16.4   1101543654              180        3
# 12  13.0  Super Market           17.3    397305098              180        3
# ...

# %%
df1.shape
# Out:
# (29, 13)

# %%
df2 = stores[ stores['Code'].isnull()    ]
df2
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 15   NaN  Electronincs           10.4   1070859930              215        4
# 21   NaN       Apparel           15.5   1333254147              150        2
# 4    NaN  Super Market           18.7   1883321582              175        2
# 26   NaN  Super Market           26.0    711375353               91        2
# 27   NaN  Super Market           30.4    886631610              113        2
#
#     Total number of estb  Product line sales as % of total sales  Rank  \
# 15                 86686                                     1.3   1.5
# 21                168897                                     4.3  10.0
# 4                 270472                                    24.7  16.0
# 26                 57339                                     2.0  29.0
# 27                 74480                                     5.4  31.5
#
#     sales_per_cust_11  sales_per_cust1  sales_per_cust_22 stores_level
# ...

# %%
## copy the df
stores1 = stores
stores1
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
### duplicated records

stores_duplicated = stores1.loc[stores1.duplicated(),]

stores_duplicated
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 32  31.0       Apparel           15.0   1115016252              335        4
# 33  32.0  Electronincs           21.4   1237304404              109        2
#
#     Total number of estb  Product line sales as % of total sales  Rank  \
# 32                125658                                     7.5   6.5
# 33                123206                                     6.4  23.0
#
#     sales_per_cust_11  sales_per_cust1  sales_per_cust_22 stores_level
# 32       3.328407e+06     3.328407e+06         1115016587         High
# 33       1.135142e+07     1.135142e+07         1237304513         High

# %%
# Drop duplicates

stores_1 = stores.drop_duplicates()

# %%
#stores = stores.drop_duplicates()

# %%
stores_duplicated = stores_1.loc[stores_1.duplicated(), ]
stores_duplicated
# Out:
# Empty DataFrame
# Columns: [Code, StoreType, OperatingCost, Total_Sales, Total_Customers, Segment, Total number of estb, Product line sales as % of total sales, Rank, sales_per_cust_11, sales_per_cust1, sales_per_cust_22, stores_level]
# Index: []

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4    NaN  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
stores.shape
# Out:
# (34, 8)

# %%
stores.columns
# Out:
# Index(['Code', 'StoreType', 'OperatingCost', 'Total_Sales', 'Total_Customers',
#        'Segment', 'Total number of estb',
#        'Product line sales as % of total sales'],
#       dtype='object')

# %%
s1 = stores.drop('StoreType' , axis=1)
s1
# Out:
#     Code  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0           21.0   2179474632              110        4
# 1    2.0           21.0      5037027              110        4
# 2    3.0           22.8   1437362017               93        1
# 3    4.0           21.4   1495953548              110        1
# 4    NaN           18.7   1883321582              175        2
# 5    6.0           18.1   1420570094              105        1
# 6    7.0           14.3   1374569510              245        4
# 7    8.0           24.4   1094166173               62        2
# 8    9.0           22.8   1182772215               95        2
# 9   10.0           19.2    891982615              123        4
# 10  11.0           17.8    427475654              123        4
# 11  12.0           16.4   1101543654              180        3
# 12  13.0           17.3    397305098              180        3
# 13  14.0           15.2    960625804              180        3
# ...

# %%
s2 = stores.drop(['Code', 'StoreType', 'Total_Sales'] , axis=1)
s2
# Out:
#     OperatingCost  Total_Customers  Segment  Total number of estb  \
# 0            21.0              110        4                361300
# 1            21.0              110        4                  2515
# 2            22.8               93        1                200112
# 3            21.4              110        1                229623
# 4            18.7              175        2                270472
# 5            18.1              105        1                176345
# 6            14.3              245        4                176243
# 7            24.4               62        2                147960
# 8            22.8               95        2                193713
# 9            19.2              123        4                106941
# 10           17.8              123        4                 34619
# 11           16.4              180        3                161210
# 12           17.3              180        3                 28056
# ...

# %%
stores.isnull().sum()
# Out:
# Code                                      5
# StoreType                                 0
# OperatingCost                             0
# Total_Sales                               0
# Total_Customers                           0
# Segment                                   0
# Total number of estb                      0
# Product line sales as % of total sales    0
# dtype: int64

# %%
x1 = stores['Code'].median()
x1
# Out:
# 17.0

# %%
stores['Code'] = stores['Code'].fillna(x1)

# %%
stores.isna().sum()
# Out:
# Code                                      0
# StoreType                                 0
# OperatingCost                             0
# Total_Sales                               0
# Total_Customers                           0
# Segment                                   0
# Total number of estb                      0
# Product line sales as % of total sales    0
# dtype: int64

# %%
stores
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    1.0  Electronincs           21.0   2179474632              110        4
# 1    2.0       Apparel           21.0      5037027              110        4
# 2    3.0  Super Market           22.8   1437362017               93        1
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4   17.0  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# ...

# %%
s4 = stores.drop([0,2] , axis=0)
s4
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 1    2.0       Apparel           21.0      5037027              110        4
# 3    4.0  Super Market           21.4   1495953548              110        1
# 4   17.0  Super Market           18.7   1883321582              175        2
# 5    6.0       Apparel           18.1   1420570094              105        1
# 6    7.0       Apparel           14.3   1374569510              245        4
# 7    8.0  Electronincs           24.4   1094166173               62        2
# 8    9.0  Electronincs           22.8   1182772215               95        2
# 9   10.0       Apparel           19.2    891982615              123        4
# 10  11.0  Super Market           17.8    427475654              123        4
# 11  12.0  Super Market           16.4   1101543654              180        3
# 12  13.0  Super Market           17.3    397305098              180        3
# ...

# %%
s5 = s4.reset_index().drop('index',axis=1)
s5
# Out:
#     Code     StoreType  OperatingCost  Total_Sales  Total_Customers  Segment  \
# 0    2.0       Apparel           21.0      5037027              110        4
# 1    4.0  Super Market           21.4   1495953548              110        1
# 2   17.0  Super Market           18.7   1883321582              175        2
# 3    6.0       Apparel           18.1   1420570094              105        1
# 4    7.0       Apparel           14.3   1374569510              245        4
# 5    8.0  Electronincs           24.4   1094166173               62        2
# 6    9.0  Electronincs           22.8   1182772215               95        2
# 7   10.0       Apparel           19.2    891982615              123        4
# 8   11.0  Super Market           17.8    427475654              123        4
# 9   12.0  Super Market           16.4   1101543654              180        3
# 10  13.0  Super Market           17.3    397305098              180        3
# ...
